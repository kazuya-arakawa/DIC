# %% [markdown]
# http://www.jspf.or.jp/Journal/PDF_JSPF/jspf2009_09/jspf2009_09-620.pdf
#
# ・フーリエ成分X(f)
#
#
#  周期fの波の振幅、|X(f)|^2はその波のエネルギーに相当
#
# ・パワースペクトル=密度関数
#
#
#  周期Tでの平均エネルギーとして定義lim->∞ |X(f)|^2/T
#
#  パワースペクトルとエネルギースペクトルの定義
#  (https://www.astrobio.k.u-tokyo.ac.jp/tajika/class/kiso2/fourier1.pdf)
#
# ・解析区間Tの設定
#
#
#  最大の周期Tが含まれるように設定(サンプリング時間>最大周期)
#
# ・最高周波数の制約
#
#
#  エイリアシング(折り返し雑音)が起きないように、ナイキスト周波数以上のサンプリング速度必要
#  サンプリング速度Δtの時、計測可能な周波数は1/2Δtまで⇒普通最大計測周波数fmaxに対し、
#  √2fmaxぐらいのサンプリング周波数(https://www.keyence.co.jp/ss/products/recorder/lab/acceleration/improvement.jsp)
#
# ・アンサンブル平均とウィンドウ（窓関数）
#
#
#  区間Tをサンプリングしたときに、時刻の異なる区間Tでスペクトルを計算すると両者は一致しない。
#  その解決方法として、複数の区間Tの平均を取るのがアンサンブル平均。
#  時系列の分散が
#  ウィンドウは波形に不連続点があるときにGibss現象を起こさないようにスムーズにつなげる関数。
#  ウィンドウをかけると振幅を減衰することに繋がるので、補正で修正する必要あり。
#  (http://www.eri.u-tokyo.ac.jp/people/knishida/Lecture/Timeseries_power.pdf)
# 1. 時系列データを細かい時系列に分ける
# 2. トレンドを除去:長周期成分の除去
# 3. tapering する:不連続が生じる事を防ぐ
# 4. 分割した時系列に対して DFT する
# 5. Window 関数 w(t) の効果の補正
# 6. 分割した時系列に対してパワースペクトルを計算
# 7. 推定誤差の低減のためパワースペクトルを平均化する
#
# ・相互相関関数
#
#  二つの配列・ベクトルの類似度を確認する関数、相関大
#  (https://www.ikko.k.hosei.ac.jp/~matlab/xcorr.pdf)
#
# ・基本的なテンプレートマッチング
#
# http://isl.sist.chukyo-u.ac.jp/Archives/tm.html
#
# ・画像相関法の理論解説
#
# https://repository.kulib.kyoto-u.ac.jp/dspace/bitstream/2433/85394/1/D_Shishido_Nobuyuki.pdf

# %%
# -*- coding: utf-8 -*-
import cv2
import numpy as np

# 入力画像とテンプレート画像をで取得
img = cv2.imread("C:/github/sample/python/opencv/template-matching/input.png")
temp = cv2.imread("C:/github/sample/python/opencv/template-matching/temp.png")

# グレースケール変換
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
temp = cv2.cvtColor(temp, cv2.COLOR_RGB2GRAY)

# テンプレート画像の高さ・幅
h, w = temp.shape

# テンプレートマッチング（OpenCVで実装）
match = cv2.matchTemplate(gray, temp, cv2.TM_SQDIFF_NORMED)
min_value, max_value, min_pt, max_pt = cv2.minMaxLoc(match)
pt = min_pt

# テンプレートマッチングの結果を出力
cv2.rectangle(img, (pt[0], pt[1]), (pt[0] + w, pt[1] + h), (0, 0, 200), 3)
cv2.imwrite("C:/github/sample/python/opencv/template-matching/sad1.png", img)
